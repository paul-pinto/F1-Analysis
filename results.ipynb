# %%
import pandas as pd

# Ver el calendario
schedule = pd.read_parquet("data/raw/schedule_2026.parquet")
print(schedule[["RoundNumber", "EventName", "EventDate"]].head(10))

# Ver resultados de la primera carrera
results = pd.read_parquet("data/raw/results_2026_Australian_Grand_Prix.parquet")
print(results[["Position", "FullName", "TeamName", "Points"]].head(10))

# Ver las primeras vueltas
laps = pd.read_parquet("data/raw/laps_2026_Australian_Grand_Prix.parquet")
print(laps[["Driver", "LapNumber", "LapTime", "Sector1Time"]].head(10))
# Out:
#    RoundNumber              EventName  EventDate
# 0            0     Pre-Season Testing 2026-02-13
# 1            0     Pre-Season Testing 2026-02-20
# 2            1  Australian Grand Prix 2026-03-08
# 3            2     Chinese Grand Prix 2026-03-15
# 4            3    Japanese Grand Prix 2026-03-29
# 5            4       Miami Grand Prix 2026-05-03
# 6            5    Canadian Grand Prix 2026-05-24
# 7            6      Monaco Grand Prix 2026-06-07
# 8            7   Barcelona Grand Prix 2026-06-14
# 9            8    Austrian Grand Prix 2026-06-28
#    Position           FullName         TeamName  Points
# 0       1.0     George Russell         Mercedes    25.0
# 1       2.0     Kimi Antonelli         Mercedes    18.0
# 2       3.0    Charles Leclerc          Ferrari    15.0
# 3       4.0     Lewis Hamilton          Ferrari    12.0
# 4       5.0       Lando Norris          McLaren    10.0
# 5       6.0     Max Verstappen  Red Bull Racing     8.0
# ...
